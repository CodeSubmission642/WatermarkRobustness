# %%
# %matplotlib inline 
import sys, os
base_path = os.getcwd()[0:os.getcwd().rfind('Watermark')] + "Watermark/"
sys.path.append(base_path) 

import matplotlib.pyplot as plt
from src.usenix_main import usenix_whitebox
from src.models import get_deep_cnn_for_cifar, get_lenet_model_for_mnist
from src.preprocess_data import load_cifar_images, load_mnist_images
from src.util import plot_whitebox
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/nlukas/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Description
# In this notebook we run an optimized whitebox attack with regularization to remove the watermark.

# %%
surr_model, all_history = usenix_whitebox(
     load_dataset_func=load_cifar_images,
     dataset_label="CIFAR",
     load_wm_model_func=get_deep_cnn_for_cifar,
     owner_data_size=25000,
     total_owner_data_size=100000,
     key_length=35,
     wm_boost_factor=100,
     attacker_data_size=25000,
     total_attacker_data_size=100000,
     attacker_data_size_reg=7000,
     epochs_embed=20,
     epochs_reg=30,
     epochs_surr=20,
     freeze_first_layers=0,
     patience_reg=2,
     early_stopping_wm_reg=0.2,  
     lr_surr=0.001,  
     reg_whitebox=0.005,
     reg_surr=0,
     batchsize_reg=64,
     batchsize_surr=64,
     cache_embed_wm="usenix_cifar",
     cache_reg_model=None,
     cache_surr_model=None,
     verbose=True
)
# Out:
# [1/5] USENIX Whitebox Attack: Loading CIFAR data
#       Owner data: 100000 Attacker Data: 100000
#      Found cached training data for owner_data100000100000
#      Found cached training data for attacker_data100000100000
# [2/5] Training the network with 35 keys each repeated 100 times)
# WARNING:tensorflow:From /home/nlukas/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/nlukas/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#       Skipping embedding of wm and use a cached entry instead
# 100000/100000 [==============================] - 75s 749us/step
#     Done! Original models accuracy on attackers data: 0.80228
# [3/5] Labeling the attackers data with the original model
# [4/5] Removing the watermark with the regularization attack.. 0
# Train on 7000 samples, validate on 10000 samples
# Epoch 1/30
# 7000/7000 [==============================] - 32s 5ms/step - loss: 127.1691 - acc: 0.8930 - val_loss: 79.3699 - val_acc: 0.7315
# => Time: : 32.15370535850525
# Confusion matrix, without normalization
# => watermark_val: 0.8571428571428571
# Epoch 2/30
# 7000/7000 [==============================] - 30s 4ms/step - loss: 52.6146 - acc: 0.9069 - val_loss: 34.6383 - val_acc: 0.5302
# => Time: : 30.22204828262329
# Confusion matrix, without normalization
# => watermark_val: 0.4000000017029898
# Epoch 3/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 23.5876 - acc: 0.9039 - val_loss: 17.9169 - val_acc: 0.4374
# => Time: : 28.959877252578735
# Confusion matrix, without normalization
# => watermark_val: 0.28571428656578063
# Epoch 4/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 12.5409 - acc: 0.8969 - val_loss: 10.9300 - val_acc: 0.4250
# => Time: : 29.116088151931763
# Confusion matrix, without normalization
# => watermark_val: 0.25714285799435205
# Epoch 5/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 7.7929 - acc: 0.8861 - val_loss: 7.4839 - val_acc: 0.5014
# => Time: : 29.167733669281006
# Confusion matrix, without normalization
# => watermark_val: 0.2000000008514949
# Epoch 6/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 5.4338 - acc: 0.8840 - val_loss: 5.5738 - val_acc: 0.5364
# => Time: : 29.105913400650024
# Confusion matrix, without normalization
# => watermark_val: 0.2000000008514949
# Epoch 7/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 4.0712 - acc: 0.8871 - val_loss: 4.4663 - val_acc: 0.5328
# => Time: : 29.07896637916565
# Confusion matrix, without normalization
# => watermark_val: 0.20000000170298984
# Epoch 8/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 3.2482 - acc: 0.8824 - val_loss: 3.6347 - val_acc: 0.6105
# => Time: : 29.011773347854614
# Confusion matrix, without normalization
# => watermark_val: 0.28571428741727556
# Epoch 9/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 2.7336 - acc: 0.8780 - val_loss: 3.2549 - val_acc: 0.6193
# => Time: : 29.40503692626953
# Confusion matrix, without normalization
# => watermark_val: 0.22857142857142856
# Epoch 10/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 2.3632 - acc: 0.8850 - val_loss: 2.6988 - val_acc: 0.6992
# => Time: : 29.272146463394165
# Confusion matrix, without normalization
# => watermark_val: 0.25714285799435205
# Epoch 11/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 2.1140 - acc: 0.8803 - val_loss: 2.5540 - val_acc: 0.6887
# => Time: : 28.867119550704956
# Confusion matrix, without normalization
# => watermark_val: 0.25714285799435205
# Epoch 12/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 1.8849 - acc: 0.8881 - val_loss: 2.3947 - val_acc: 0.6643
# => Time: : 29.270090341567993
# Confusion matrix, without normalization
# => watermark_val: 0.17142857228006636
# (Early stopping) Current: [0.17142857228006636] My value: 0.2
# Early Stopping By WM: Patience decreased to 1
# Epoch 13/30
# 7000/7000 [==============================] - 31s 4ms/step - loss: 1.7656 - acc: 0.8774 - val_loss: 2.3136 - val_acc: 0.6696
# => Time: : 30.96002697944641
# Confusion matrix, without normalization
# => watermark_val: 0.2000000008514949
# Epoch 14/30
# 7000/7000 [==============================] - 29s 4ms/step - loss: 1.6517 - acc: 0.8817 - val_loss: 2.1912 - val_acc: 0.6731
# => Time: : 29.234246253967285
# Confusion matrix, without normalization
# => watermark_val: 0.17142857228006636
# (Early stopping) Current: [0.17142857228006636] My value: 0.2
# Early Stopping By WM: Patience decreased to 0
# Epoch 15/30
# 7000/7000 [==============================] - 30s 4ms/step - loss: 1.5753 - acc: 0.8760 - val_loss: 2.5094 - val_acc: 0.6275
# => Time: : 30.278902292251587
# Confusion matrix, without normalization
# => watermark_val: 0.14285714285714285
# (Early stopping) Current: [0.14285714285714285] My value: 0.2
# Epoch 00014: early stopping THR
# [5/5] Training the surrogate model
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/20
# 100000/100000 [==============================] - 319s 3ms/step - loss: 0.7077 - acc: 0.7687 - val_loss: 0.7455 - val_acc: 0.7636
# => Time: : 319.1256136894226
# Confusion matrix, without normalization
# => watermark_val: 0.2857142857142857
# Epoch 2/20
# 100000/100000 [==============================] - 318s 3ms/step - loss: 0.5562 - acc: 0.8193 - val_loss: 0.6698 - val_acc: 0.7848
# => Time: : 318.02030777931213
# Confusion matrix, without normalization
# => watermark_val: 0.3142857142857143
# Epoch 3/20
# 100000/100000 [==============================] - 313s 3ms/step - loss: 0.4884 - acc: 0.8451 - val_loss: 0.6121 - val_acc: 0.8069
# => Time: : 313.1951127052307
# Confusion matrix, without normalization
# => watermark_val: 0.2571428571428571
# Epoch 4/20
# 100000/100000 [==============================] - 315s 3ms/step - loss: 0.4401 - acc: 0.8639 - val_loss: 0.6867 - val_acc: 0.7830
# => Time: : 314.8066487312317
# Confusion matrix, without normalization
# => watermark_val: 0.2000000008514949
# Epoch 5/20
# 100000/100000 [==============================] - 315s 3ms/step - loss: 0.4031 - acc: 0.8795 - val_loss: 0.6130 - val_acc: 0.8100
# => Time: : 315.1387026309967
# Confusion matrix, without normalization
# => watermark_val: 0.3142857151372092
# Epoch 6/20
# 100000/100000 [==============================] - 314s 3ms/step - loss: 0.3744 - acc: 0.8922 - val_loss: 0.6211 - val_acc: 0.8086
# => Time: : 314.3778009414673
# Confusion matrix, without normalization
# => watermark_val: 0.17142857142857143
# Epoch 7/20
# 100000/100000 [==============================] - 315s 3ms/step - loss: 0.3503 - acc: 0.9036 - val_loss: 0.6109 - val_acc: 0.8184
# => Time: : 314.9914917945862
# Confusion matrix, without normalization
# => watermark_val: 0.22857142857142856
# Epoch 8/20
# 100000/100000 [==============================] - 315s 3ms/step - loss: 0.3299 - acc: 0.9117 - val_loss: 0.6651 - val_acc: 0.8101
# => Time: : 314.7350318431854
# Confusion matrix, without normalization
# => watermark_val: 0.2285714294229235
# Epoch 9/20
# 100000/100000 [==============================] - 315s 3ms/step - loss: 0.3143 - acc: 0.9196 - val_loss: 0.5957 - val_acc: 0.8233
# => Time: : 314.7200367450714
# Confusion matrix, without normalization
# => watermark_val: 0.3142857151372092
# Epoch 10/20
#  85632/100000 [========================>.....] - ETA: 44s - loss: 0.3001 - acc: 0.9267

# %%
tmp_val = all_history[2].history["val_acc"][:-1]
tmp_wm = all_history[2].history["watermark_val"][:-1]
print(tmp)
print(tmp_wm)
# Out:
# [0.7636, 0.7848, 0.8069, 0.783, 0.81, 0.8086, 0.8184, 0.8101, 0.8233, 0.8143, 0.8173, 0.8085, 0.8154, 0.8236, 0.816, 0.8233, 0.8194, 0.8243, 0.8224]
# [0.2857142857142857, 0.3142857142857143, 0.2571428571428571, 0.2000000008514949, 0.3142857151372092, 0.17142857142857143, 0.22857142857142856, 0.2285714294229235, 0.3142857151372092, 0.25714285799435205, 0.3142857151372092, 0.25714285799435205, 0.25714285799435205, 0.3428571437086378, 0.25714285799435205, 0.28571428656578063, 0.17142857142857143, 0.2571428571428571, 0.22857142857142856]

# %%
all_history[2].history["watermark_val"] = tmp_wm

# %%
tmp_wm = [0.2857142857142857, 0.3142857142857143, 0.2571428571428571, 0.2000000008514949, 0.3142857151372092, 0.17142857142857143, 0.22857142857142856, 0.2285714294229235, 0.3142857151372092, 0.25714285799435205, 0.3142857151372092, 0.25714285799435205, 0.25714285799435205, 0.3428571437086378, 0.25714285799435205, 0.28571428656578063, 0.17142857142857143, 0.2571428571428571, 0.22857142857142856]

# %%
print(all_history[2].history["time"])
# Out:
# [319.1256136894226, 318.02030777931213, 313.1951127052307, 314.8066487312317, 315.1387026309967, 314.3778009414673, 314.9914917945862, 314.7350318431854, 314.7200367450714, 315.60970520973206, 315.6495282649994, 315.8909614086151, 316.12429118156433, 316.9272050857544, 316.8396625518799, 316.16108798980713, 315.3634738922119, 316.7842426300049, 316.322692155838, 315.77937269210815]

# %%
plot_whitebox(all_history, blackbox_surr_val_acc=0.803)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'watermark_loss', 'watermark_val', 'time', 'time_total'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'watermark_loss', 'watermark_val', 'time', 'time_total'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'watermark_loss', 'watermark_val', 'time', 'time_total'])

# %%
for history in all_history:
    print(sum(history.history["time"])/60)
blackbox_surr_val_acc=0.798
ctr =0
for time, acc in zip(all_history[2].history["time"], all_history[2].history["val_acc"]):
    if acc > blackbox_surr_val_acc:
        print("Time: {}, Acc: {}".format(sum(all_history[1].history["time"])/60+sum(all_history[2].history["time"][:ctr+1])/60, acc))
        break
    ctr += 1
# Out:
# 112.53630279302597
# 7.401727910836538
# 105.27604949871699
# Time: 23.240745147069298, Acc: 0.8069
